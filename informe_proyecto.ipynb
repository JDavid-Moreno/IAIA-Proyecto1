# %% [markdown]
# # Proyecto 1 IAIA
#
# **Integrantes:** Daniel Felipe Sua Siempira, Juan David Moreno D'Aleman
#
# **Equipo:** Azul
#
#
# ---

# %% [markdown]
# **Idea del Proyecto:**
# El objetivo principal de este proyecto es calcular la mejor ruta (la mas rapida) para ir de una estacion de Transmilenio a otra.
#
# **Nota:** Para la implementacion de este sistema de busqueda, se reutilizo y adapto codigo desarrollado previamente en el Laboratorio 1

# %% [markdown]
# ## 1. Definicion de Rutas y Estaciones (routes.py)
#
# En esta primera seccion definimos las rutas de nuestro problema. El diccionario `routes` contiene la informacion de cada ruta de Transmilenio y la secuencia exacta de estaciones por las que pasa.
#
# Adicionalmente, implementamos la funcion `build_routes_by_station` que nos permite invertir esta logica: dada una estacion especifica, nos devuelve una lista con todas las rutas que hacen parada en ella. Esto es crucial para saber que opciones de transbordo tenemos en cada punto.

# %%
routes = {
    "B12": {
        "name": "B12",
        "stations": [
            "Portal Sur", "Perdomo", "General Santander", "Comuneros",
            "Ricaurte", "Avenida El Dorado", "Universidad Nacional",
            "7 de Agosto", "NQS Calle 75 - Zona M", "La Castellana",
            "Calle 100", "Calle 127", "Prado Veraniego", "Calle 142",
            "Toberin", "Portal Norte",
        ],
    },
    "G12": {
        "name": "G12",
        "stations": [
            "Portal Norte", "Toberin", "Calle 142", "Prado Veraniego",
            "Calle 127", "Calle 100", "La Castellana",
            "NQS Calle 75 - Zona M", "7 de Agosto", "Universidad Nacional",
            "Avenida El Dorado", "Ricaurte", "Comuneros",
            "General Santander", "Perdomo", "Portal Sur",
        ],
    },
    "B10": {
        "name": "B10",
        "stations": [
            "Portal de la 80", "Carrera 90", "Avenida Cali",
            "Granja - Carrera 77", "Boyaca", "Avenida 68", "Carrera 53",
            "Carrera 47", "Calle 85", "Calle 100", "Alcala", "Calle 146",
            "Mazuren", "Toberin", "Portal Norte",
        ],
    },
    "B26": {
        "name": "B26",
        "stations": [
            "Portal Americas", "Biblioteca Tintal", "Transversal 86",
            "Banderas", "Mandalay", "Avenida Americas - Avenida Boyaca",
            "Heroes", "Calle 85", "Virrey", "Calle 100", "Calle 127",
            "Alcala",
        ],
    },
    "B28": {
        "name": "B28",
        "stations": [
            "Portal Americas", "Biblioteca Tintal", "Banderas", "Marsella",
            "Zona Industrial", "CDS - Carrera 32", "La Castellana",
            "Calle 106", "Pepe Sierra", "Prado Veraniego", "Calle 146",
            "Calle 161", "Portal Norte",
        ],
    },
    "F28": {
        "name": "F28",
        "stations": [
            "Portal Norte", "Calle 161", "Calle 146", "Prado Veraniego",
            "Pepe Sierra", "Calle 106", "La Castellana", "CDS - Carrera 32",
            "Zona Industrial", "Marsella", "Banderas", "Biblioteca Tintal",
            "Portal Americas",
        ],
    },
    "E32": {
        "name": "E32",
        "stations": [
            "Portal Americas", "Banderas", "CAD", "7 de Agosto",
            "NQS Calle 75 - Zona M",
        ],
    },
    "C19": {
        "name": "C19",
        "stations": [
            "Portal Americas", "Biblioteca Tintal", "Banderas", "Mandalay",
            "Marsella", "Distrito Grafiti", "CDS - Carrera 32", "Ricaurte",
            "De la sabana", "Calle 26", "Calle 57", "Flores", "Suba - Calle 95",
            "Suba - Calle 100", "Puente Largo", "Suba - Avenida Boyaca",
            "21 Angeles", "Suba - Transversal 91",
            "La Campina", "Portal Suba",
        ],
    },
    "F19": {
        "name": "F19",
        "stations": [
            "Portal Suba", "La Campina", "Suba - Transversal 91",
            "21 Angeles", "Suba - Avenida Boyaca", "Puente Largo",
            "Suba - Calle 100", "Suba - Calle 95", "Flores", "Calle 57",
            "Calle 26", "De La Sabana", "Ricaurte", "CDS - Carrera 32",
            "Distrito Grafiti", "Marsella", "Mandalay", "Banderas",
            "Biblioteca Tintal", "Portal Americas",
        ],
    },
    "F26": {
        "name": "F26",
        "stations": [
            "Portal de la 80", "Carrera 90", "Avenida Cali",
            "Granja - Carrera 77", "Boyaca", "Avenida 68", "Carrera 53",
            "Carrera 47", "Calle 85", "Calle 100", "Alcala", "Calle 146",
            "Mazuren", "Toberin", "Portal Norte",
        ],
    },
    "B13": {
        "name": "B13",
        "stations": [
            "Portal Tunal", "Biblioteca", "Calle 40 Sur", "Quiroga",
            "Restrepo", "Hortua", "Calle 22", "Flores", "Calle 85",
            "Calle 106", "Calle 127", "Calle 142", "Calle 146",
            "Mazuren", "Calle 161", "Portal Norte",
        ],
    },
    "H13": {
        "name": "F32",
        "stations": [
            "Portal Norte", "Calle 161", "Mazuren", "Calle 146",
            "Calle 142", "Calle 127", "Calle 106", "Calle 85",
            "Flores", "Calle 22", "Hortua", "Restrepo", "Quiroga",
            "Calle 40 Sur", "Biblioteca", "Portal Tunal",
        ],
    },
    "C17": {
        "nombre": "C17",
        "stations": [
            "Portal Usme", "Danubio", "Consuelo", "Socorro",
            "Santa Lucia", "Quiroga", "Restrepo", "Hortua",
            "Guatoque - Veraguas", "Paloquemao", "Avenida El Dorado",
            "Universidad Nacional", "7 de Agosto", "San Martin",
            "Suba - Calle 95", "Suba Calle 100", "Puentelargo",
            "Avenida Suba - Calle 116", "Niza - Calle 127",
            "Suba - Tv. 91", "La Campina", "Portal Suba",
        ],
    },
    "H17": {
        "nombre": "H17",
        "stations": [
            "Portal Suba", "La Campina", "Suba - Tv. 91",
            "Niza - Calle 127", "Avenida Suba - Calle 116",
            "Puentelargo", "Suba Calle 100", "Suba - Calle 95",
            "San Martin", "7 de Agosto", "Universidad Nacional",
            "Avenida El Dorado", "Paloquemao", "Guatoque - Veraguas",
            "Hortua", "Restrepo", "Quiroga", "Santa Lucia",
            "Socorro", "Consuelo", "Danubio", "Portal Usme",
        ],
    },
    "C25": {
        "nombre": "C25",
        "stations": [
            "Portal 20 de Julio", "Country Sur", "Av. Primero de Mayo",
            "Estacion San Bernardo", "Bicentenario", "Tygua-San Jose",
            "Guatoque - Veraguas", "Ricaurte", "Campin - UAN",
            "Movistar Arena", "Avenida Chile", "NQS Calle 75",
            "San Martin", "Suba - Calle 95", "Niza - Calle 127",
            "Suba - Av. Boyaca", "21 Angeles", "Suba - Tv. 91",
            "La Campina", "Portal Suba",
        ],
    },
    "L25": {
        "nombre": "L25",
        "stations": [
            "Portal Suba", "La Campina", "Suba - Tv. 91",
            "21 Angeles", "Suba - Av. Boyaca", "Niza - Calle 127",
            "Suba - Calle 95", "San Martin", "NQS Calle 75",
            "Avenida Chile", "Movistar Arena", "Campin - UAN",
            "Ricaurte", "Guatoque - Veraguas", "Tygua-San Jose",
            "Bicentenario", "Estacion San Bernardo", "Av. Primero de Mayo",
            "Country Sur", "Portal 20 de Julio",
        ],
    },
}

def build_routes_by_station(routes: dict):
    routes_by_station: dict[str, list[str]] = {}
    for route_id, data in routes.items():
        for station in data["stations"]:
            routes_by_station.setdefault(station, [])
            if route_id not in routes_by_station[station]:
                routes_by_station[station].append(route_id)
    return routes_by_station

routes_by_station = build_routes_by_station(routes)

# %% [markdown]
# ## 2. Construccion del Grafo Físico y Heuristica (station_graph.py)
#
# Para guiar la busqueda de manera inteligente, necesitamos una estimacion de que tan lejos estamos del destino (heuristica). Aqui creamos un grafo que representa la red fisica de troncales de Transmilenio y sus conexiones a pie (transbordos fisicos).
#
# Usamos la clase `Graph` para modelar las estaciones como nodos y las conexiones como aristas con un peso predeterminado. El metodo `shortest_distances_from` implementa un algoritmo de caminos minimos utilizando una cola de prioridad (`heapq`). Este metodo se usa mas adelante para darle a nuestro algoritmo principal una pista de hacia donde debe dirigirse.

# %%
import heapq

stations_by_corridor = {
    "A": [
        "Calle 72", "Flores", "Calle 57", "Marly", "Avenida 39",
        "Calle 34", "Calle 26", "Calle 22", "Avenida Jimenez",
    ],
    "B": [
        "Terminal", "Calle 187", "Portal Norte", "Toberin", "Calle 161",
        "Mazuren", "Calle 146", "Calle 142", "Alcala", "Prado Veraniego",
        "Calle 127", "Pepe Sierra", "Calle 106", "Calle 100", "Virrey",
        "Calle 85", "Heroes",
    ],
    "C": [
        "Portal Suba", "La Campina", "Suba - Transversal 91", "21 Angeles",
        "Gratamira", "Suba - Avenida Boyaca", "Niza - Calle 127",
        "Humedal Cordoba", "Avenida Suba - Calle 116", "Puente Largo",
        "Suba - Calle 100", "Suba - Calle 95", "Rionegro", "San Martin",
    ],
    "D": [
        "Portal de la 80", "Quirigua", "Carrera 90", "Avenida Cali",
        "Granja - Carrera 77", "Minuto de Dios", "Boyaca", "Las Ferias",
        "Avenida 68", "Carrera 53", "Carrera 47", "Escuela Militar", "Polo",
    ],
    "E": [
        "La Castellana", "NQS Calle 75 - Zona M", "7 de Agosto",
        "Movistar Arena", "Campin - Universidad Antonio Narino",
        "Universidad Nacional", "Avenida El Dorado", "CAD", "Paloquemao",
        "Ricaurte",
    ],
    "F": [
        "Tibanica - Primavera", "Los Laureles", "Islandia", "Portal Americas",
        "Biblioteca Tintal", "Transversal 86", "Banderas", "Mandalay",
        "Avenida Americas - Avenida Boyaca", "Marsella", "Pradera",
        "Distrito Grafiti", "Puente Aranda", "Carrera 43", "Zona Industrial",
        "CDS - Carrera 32", "Ricaurte", "San Facon - Carrera 22",
        "De La Sabana", "Avenida Jimenez",
    ],
    "G": [
        "Comuneros", "Santa Isabel", "Calle 30 Sur", "Calle 38A Sur",
        "General Santander", "Alqueria", "Venecia", "Sevillana",
        "Madelena", "Perdomo", "Portal Sur", "Bosa", "La Despensa",
        "Leon XIII", "Terreros - Hospital Cardiovascular", "San Mateo",
    ],
    "H": [
        "Hortua", "Narino", "Fucha", "Restrepo", "Olaya", "Quiroga",
        "Calle 40 Sur", "Santa Lucia", "Socorro", "Consuelo", "Molinos",
        "Danubio", "Portal Usme", "Biblioteca", "Parque", "Portal Tunal",
    ],
    "J": [
        "San Victorino", "Museo del Oro",
        "Las Aguas - Centro Colombo Americano", "Universidades",
    ],
    "K": [
        "Portal El Dorado", "Modelia", "Normandia", "Avenida Rojas",
        "El Tiempo", "Salitre - El Greco", "CAN", "Gobernacion",
        "Quinta Paredes", "Corferias",
        "Ciudad Universitaria - Loteria de Bogota", "Concejo de Bogota",
        "Centro Memoria", "Universidades",
    ],
    "L": [
        "San Diego", "Las Nieves", "San Victorino", "Bicentenario",
        "San Bernardo", "Policarpa",
        "Ciudad Jardin - Universidad Antonio Narino", "Avenida 1 de Mayo",
        "Country Sur", "Portal 20 de Julio",
    ],
    "M": [
        "Museo Nacional",
    ],
}

inter_corridor_connections = [
    ("Heroes", "Polo"),
    ("Calle 72", "Polo"),
    ("NQS Calle 75 - Zona M", "Polo"),
    ("NQS Calle 75 - Zona M", "Escuela Militar"),
    ("NQS Calle 75 - Zona M", "San Martin"),
    ("Calle 100", "La Castellana"),
    ("Avenida El Dorado", "Ciudad Universitaria - Loteria de Bogota"),
    ("Avenida Jimenez", "Hortua"),
    ("Avenida Jimenez", "Museo del Oro"),
    ("Museo Nacional", "Centro Memoria"),
    ("Calle 26", "Centro Memoria"),
    ("Ricaurte", "Comuneros"),
]

class Graph:
    def __init__(self):
        self.adjacency = {}

    def add_edge(self, a, b, weight):
        self.adjacency.setdefault(a, [])
        self.adjacency.setdefault(b, [])
        self.adjacency[a].append((b, weight))
        self.adjacency[b].append((a, weight))

    def shortest_distances_from(self, source):
        distances = {source: 0}
        visited = set()
        heap = [(0, source)]

        while heap:
            dist, node = heapq.heappop(heap)
            if node in visited:
                continue
            visited.add(node)
            for neighbor, weight in self.adjacency.get(node, []):
                new_dist = dist + weight
                if neighbor not in distances or new_dist < distances[neighbor]:
                    distances[neighbor] = new_dist
                    heapq.heappush(heap, (new_dist, neighbor))
        return distances

EDGE_WEIGHT = 2

def build_graph():
    graph_instance = Graph()
    for corridor, stations in stations_by_corridor.items():
        for i in range(len(stations) - 1):
            graph_instance.add_edge(stations[i], stations[i + 1], EDGE_WEIGHT)
    for a, b in inter_corridor_connections:
        graph_instance.add_edge(a, b, EDGE_WEIGHT)
    return graph_instance

graph = build_graph()

# %% [markdown]
# ## 3. Algoritmo de Busqueda A* (faster_route.py)
#
# Este es la clase principal del proyecto. Consiste en:
# 1. **Estados:** Representados por una tupla `(estacion_actual, ruta_actual)`.
# 2. **Acciones:** Bajar de un bus, subirse a una nueva ruta, o moverse a la siguiente estacion de la ruta actual.
# 3. **Costo de Acciones:** Evaluamos el tiempo que toma viajar entre estaciones (`TRAVEL_TIME`), detenerse (`DWELL_TIME`) y hacer transbordos (`TRANSFER_TIME`).
# 4. **Heuristica:** La funcion `heuristic` utiliza las distancias precalculadas por el grafo fisico para orientar la busqueda eficientemente.
#
# La funcion `best_first_search` utiliza una frontera (`Frontier`) para explorar primero los caminos mas prometedores. Al finalizar, imprimira las indicaciones paso a paso (como subir a un bus y donde hacer transbordo) y el tiempo total.
#
# *(Nota: En Jupyter no es necesario hacer importaciones de otros archivos porque todo ya fue declarado en las celdas superiores).*

# %%
import heapq

class Node:
    def __init__(self, state, parent=None, action=None, cost=0):
        self.state = state
        self.parent = parent
        self.action = action
        self.cost = cost

    def __str__(self):
        return f"Node(state={self.state}, action={self.action}, cost={self.cost})"

    def representation(self):
        return self.state


class Frontier:
    def __init__(self, evaluation_function):
        self.evaluation_function = evaluation_function
        self.frontier_node = []
        self.count = 0

    def is_empty(self):
        return len(self.frontier_node) == 0

    def pop(self):
        if self.is_empty():
            raise Exception("empty frontier")
        delete = heapq.heappop(self.frontier_node)
        return delete[2]

    def top(self):
        if self.is_empty():
            raise Exception("empty frontier")
        return self.frontier_node[0][2]

    def add(self, node):
        value = self.evaluation_function(node)
        heapq.heappush(self.frontier_node, (value, self.count, node))
        self.count += 1


class Problem:
    def __init__(self, initial_station, goal_station, routes, graph_instance):
        self.initial_station = initial_station
        self.goal_station = goal_station
        self.routes = routes
        self.routes_by_station = build_routes_by_station(routes)
        self.initial_state = (initial_station, None)
        self.distances_to_goal = graph_instance.shortest_distances_from(goal_station)

    def is_goal(self, state):
        return state[0] == self.goal_station

    def result_actions(self, state):
        station, current_route = state
        new_states = []

        if current_route is None:
            for route_id in self.routes_by_station.get(station, []):
                new_state = (station, route_id)
                new_states.append(new_state)
        else:
            route_stations = self.routes[current_route]["stations"]
            index = route_stations.index(station)

            if index + 1 < len(route_stations):
                next_station = route_stations[index + 1]
                new_state = (next_station, current_route)
                new_states.append(new_state)

            new_state = (station, None)
            new_states.append(new_state)

        return new_states

    def action_cost(self, state, action, state_1):
        station, route = state
        station_1, route_1 = state_1

        if route is None:
            return 0

        if route_1 is None:
            if station == self.goal_station:
                return 0
            return TRANSFER_TIME

        return TRAVEL_TIME + DWELL_TIME

    def heuristic(self, state):
        station = state[0]
        return self.distances_to_goal.get(station, 0)


FAIL = Node(None)
TRAVEL_TIME = 3
DWELL_TIME = 4
TRANSFER_TIME = 5

def expand(problem_inst, node):
    state = node.state
    neighbors = problem_inst.result_actions(state)
    neighbors = list(neighbors)
    expansion = []

    for neighbor in neighbors:
        cost = problem_inst.action_cost(state, neighbor, neighbor) + node.cost
        node_1 = Node(neighbor, node, neighbor, cost)
        expansion.append(node_1)

    return expansion


def best_first_search(problem_inst, evaluation_function):
    root_node = Node(problem_inst.initial_state, None, None, 0)
    frontier = Frontier(evaluation_function)
    frontier.add(root_node)
    reached = {}

    while not frontier.is_empty():
        current_node = frontier.pop()

        if current_node.state in reached and reached[current_node.state] <= current_node.cost:
            continue

        reached[current_node.state] = current_node.cost

        if problem_inst.is_goal(current_node.state):
            return current_node

        for neighbor in expand(problem_inst, current_node):
            frontier.add(neighbor)

    return FAIL


def path_actions(node):
    nodes = []
    while True:
        nodes.append(node)
        if node.parent is None:
            break
        node = node.parent
    nodes.reverse()
    actions = []

    for n in nodes:
        action = n.state
        actions.append(action)
    return actions


def show_result(problem_inst, solution_path):
    for i in range(1, len(solution_path)):
        previous_station, previous_route = solution_path[i - 1]
        station, route = solution_path[i]

        if previous_route is None and route is not None:
            print(f"Tomar: {route}")

        elif previous_route is not None and route is None:
            if station != problem_inst.goal_station:
                print(f"Transbordo en: {station}")


problem = Problem("Portal Sur", "Portal Norte", routes, graph)

result = best_first_search(
    problem,
    lambda node: node.cost + problem.heuristic(node.state)
)

if result is FAIL:
    print("No se encontro ruta.")
else:
    solution = path_actions(result)
    show_result(problem, solution)
    print()
    print("Duracion:", result.cost, "minutos")
# Out:
# Tomar: B12
# Transbordo en: Ricaurte
# Tomar: F19
# Transbordo en: CDS - Carrera 32
# Tomar: B28
#
# Duracion: 94 minutos

# %% [markdown]
# Por ejemplo aqui, en vez de usar una ruta directa, utilzo otra ruta que necesita transbordo ya que le parecio mas rapida segun el calculo de la heuristica.
